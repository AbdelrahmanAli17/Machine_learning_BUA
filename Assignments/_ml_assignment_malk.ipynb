# %% [markdown]
# # *name: malk yasser *
# id:2023028906
# # assignment sheet 2:predict salary

# %% [markdown]
# here we imported the librarys we neded
# We also need some new sklearn tools  for splitting data, one for the model anda new one for MSE

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('employee_salary_data.csv')
print(df.head()) #only shows the first 5 rows so I can check if it loaded correctly.
x = df[["YearsExperience"]]   # X → input
y = df["Salary"]  #what i want to predict
# Out:
#    YearsExperience  Salary  Age  WorkingHoursPerWeek
# 0                1   35000   22                   38
# 1                2   38000   23                   39
# 2                3   40000   24                   40
# 3                4   45000   26                   41
# 4                5   50000   28                   42

# %% [markdown]
# here i learned that the deafult test and train are 255 and 75% so we need to custmoise it to what we need by using 0.3 to represent the 30%

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
model = LinearRegression()
model.fit(x_train, y_train) #l fit function where the model gets traind
y_pred = model.predict(x_test)

# %% [markdown]
# ig mse checks how far the guesses are from the real salaries so the smaller the number the better the model did

# %%
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 3029690.9413003814

# %% [markdown]
# 3ady what we write every section to show results w keda

# %%
plt.scatter(x_test, y_test, color='blue', label='Real Data')
plt.plot(x_test, y_pred, color='red', label='Prediction Line')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title('Salary vs Experience')
plt.legend()
plt.show()

# %% [markdown]
# the red line almost fits the blue points, so the linear model did a good job at learning this pattern

# %%
print("Slope (coefficient):", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Slope (coefficient): 4588.983050847458
# Intercept: 29029.661016949147

# %% [markdown]
# # *conclusion*

# %% [markdown]
# After training the model, I found that the slope was positive, which means that there is a direct relationship between years of experience and salary so more experience = higher salary obv,
# The MSE was small, which means the model predicted salaries are close to the real ones
